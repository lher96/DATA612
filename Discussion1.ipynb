# %% [markdown]
# Research Discussion Assignment 1
# DATA 612 - Luis Hernandez
#
# Part 1: Instagram Recommender System
#
# Instagram is a system that uses a hybrid approach as I assume all major systems do to some extent. There is a major theme in reels specifically, where content you watch will be
# reinforced almost immediately. This is where I believe they use Content based filtering to show media in the category you are engaging with in the most watch time. This will then
# show you videos similar to the videos you watch all the way through, or beyond a certain threshold. There is certainly a collaborative filtering that occurs at some point as you can
# see a clear video will be thrown in that is adjacent to your content for the type of person you may know. For example, when I watch a large amount of golf videos, I notice my suggestions will change almost instantly. I will often be then shown more fitness and luxury travel or home videos. I make it a point to downrank the suggestion with "Not Interested" and then it feels as if the bucket of suggestions slowly drifts to other topics unrelated until it circles back.
#
# Does the technique deliver a good experience or are the recommendations off-target?
#
# I do feel that within the topic the suggestions are quite accurate but rarely does instagram ever give me very good new topic suggestions. I wonder if this is a failure to recognize  me correctly in their collaborative filtering mechanism that reverts back to content based filtering. When I search for specific topics it is often extremely accurate as far as suggestions in this case. I have noticed the suggested topics become more targeted such as a transition from luxury vacation homes and vacations, to golf vacation destinations and deals for golf equipment in ads. This is a more accurate but I do think the frequency with how off target these are may be an anomaly in my case.

# %% [markdown]
# Part 2
#
# The Washington Post article was a very interesting example of how an organized group with a political motive can work to rewrtie history by preventing some sort of perspective from being expressed. In this example the buggest red flag to me would be that these reviews flooded in during pre-release of the movie. In this case, I would suggest some type of code or temporary login to verify these users had actually viewed the premier of this film. Once the movie is released in theatres this can become a much more challenging ordeal to separate true negative sentiment from organized efforts to downrate some form of media.
#
# There are many ways to combat this that will likely have negative effects for other users but mitigating this while mitigating the organized effort would be the ideal solution. First, using something like global baseline estimates I would see if this is an abnormally negative review from this user. This could be a first red flag to bucket reviews for further evaluation. Next I would have to look in the abundance of these negative reviews to see if there was a possibility of spam. It can be normal for this to happen in a short time but it would have to be after the public release of the film. In the case of social media this would be veified by account qualities such as date created, or region. It would be severely unlikely that an abundance of new users would be created and immediately produce negative comments on the same topic. This could be fixed with a waiting period from account creation. Finally, I think this would be a great time to bring in some character minimum for reviews that can run through a sentiment analysis or even an LLM to further predict the repeated tone of review. In a method somewhat akin to collaborative filtering, we could assess the repeated words from users and their connections. I would call this "anti-collaborative filtering" because the goal would be to identify herd behavior and assess if this is a genuine negative sentiment or if this is an example of consorted effort to downrank something. There will be many complications in this process but it can only be fully addressed with multiple competing angles to prevent the appearance that the website or application itself isn't creating a mechanism to push a narrative of their own. Determining when this is appropriate is incredibly difficult from a political and human perspective where many people have obscured the idea of "fact based knowledge" over the last few years but this is critical moving forward in a world where herd behavior on social media can promote terrible, inconclusive, or anti-factual beliefs.
